# %% [markdown]
# <a href="https://colab.research.google.com/github/anushirahatti/unemployment-data/blob/master/src/us_unemployment_rate_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ingest

# %%
import pandas as pd

# %%
unemployment_data = pd.read_csv("https://raw.githubusercontent.com/anushirahatti/unemployment-data/master/usable_data/unemployment_data_us.csv")
unemployment_data_state = pd.read_csv("https://raw.githubusercontent.com/anushirahatti/unemployment-data/master/usable_data/unemployment_data_us_state.csv")

# %% [markdown]
# # EDA

# %% [markdown]
# **Analyze Overall US Unemployment Data**

# %%
unemployment_data.head(5)
# Out:
#    Year Month  Primary_School      Date  ...  Asian  Hispanic   Men  Women
# 0  2010   Jan            15.3  Jan-2010  ...    8.3      12.9  10.2    7.9
# 1  2011   Jan            14.3  Jan-2011  ...    6.8      12.3   9.0    7.9
# 2  2012   Jan            13.0  Jan-2012  ...    6.7      10.7   7.7    7.6
# 3  2013   Jan            12.0  Jan-2013  ...    6.4       9.7   7.5    7.2
# 4  2014   Jan             9.4  Jan-2014  ...    4.7       8.3   6.2    5.8
#
# [5 rows x 13 columns]

# %%
unemployment_data.tail(5)
# Out:
#      Year Month  Primary_School      Date  ...  Asian  Hispanic  Men  Women
# 127  2016   Dec             7.5  Dec-2016  ...    2.7       5.9  4.4    4.3
# 128  2017   Dec             6.2  Dec-2017  ...    2.5       5.0  3.7    3.7
# 129  2018   Dec             5.8  Dec-2018  ...    3.3       4.4  3.6    3.5
# 130  2019   Dec             5.2  Dec-2019  ...    2.5       4.2  3.1    3.2
# 131  2020   Dec             NaN  Dec-2020  ...    NaN       NaN  NaN    NaN
#
# [5 rows x 13 columns]

# %%
unemployment_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 132 non-null    int64
#  1   Month                132 non-null    object
#  2   Primary_School       123 non-null    float64
#  3   Date                 132 non-null    object
#  4   High_School          123 non-null    float64
#  5   Associates_Degree    123 non-null    float64
#  6   Professional_Degree  123 non-null    float64
#  7   White                123 non-null    float64
#  8   Black                123 non-null    float64
#  9   Asian                123 non-null    float64
#  10  Hispanic             123 non-null    float64
#  11  Men                  123 non-null    float64
#  12  Women                123 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 13.5+ KB

# %%
unemployment_data = unemployment_data.dropna()

# %%
unemployment_data['Date'] =pd.to_datetime(unemployment_data.Date)
unemployment_data = unemployment_data.sort_values(by='Date', ascending=True)

# %%
unemployment_data.isna().sum()
# Out:
# Year                   0
# Month                  0
# Primary_School         0
# Date                   0
# High_School            0
# Associates_Degree      0
# Professional_Degree    0
# White                  0
# Black                  0
# Asian                  0
# Hispanic               0
# Men                    0
# Women                  0
# dtype: int64

# %%
unemployment_data.describe()
# Out:
#               Year  Primary_School  ...         Men       Women
# count   123.000000      123.000000  ...  123.000000  123.000000
# mean   2014.634146        9.329268  ...    5.848780    5.485366
# std       2.973292        3.343178  ...    2.160577    1.750910
# min    2010.000000        4.800000  ...    3.100000    3.100000
# 25%    2012.000000        6.350000  ...    3.950000    3.900000
# 50%    2015.000000        8.500000  ...    5.200000    5.000000
# 75%    2017.000000       12.250000  ...    7.600000    7.400000
# max    2020.000000       15.800000  ...   10.300000    8.400000
#
# [8 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

# %%
# multi-line plotting based on education

plt.figure(figsize=(20,10))
plt.plot( 'Date', 'Primary_School', data=unemployment_data, color='red')
plt.plot( 'Date', 'High_School', data=unemployment_data, color='yellow')
plt.plot( 'Date', 'Associates_Degree', data=unemployment_data, color='magenta')
plt.plot( 'Date', 'Professional_Degree', data=unemployment_data, color='blue')
plt.legend()

# %%
# multi-line plotting based on race

plt.figure(figsize=(20,10))
plt.plot( 'Date', 'White', data=unemployment_data, color='magenta')
plt.plot( 'Date', 'Black', data=unemployment_data, color='red')
plt.plot( 'Date', 'Asian', data=unemployment_data, color='blue')
plt.plot( 'Date', 'Hispanic', data=unemployment_data, color='yellow')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: Second argument 'White' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: Second argument 'Black' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   after removing the cwd from sys.path.

# %%
# multi-line plotting based on gender

plt.figure(figsize=(20,10))
plt.plot( 'Date', 'Men', data=unemployment_data, color='blue')
plt.plot( 'Date', 'Women', data=unemployment_data, color='magenta')
plt.legend()

# %% [markdown]
# **Analyze Unemployment Data State-Wise**

# %%
unemployment_data_state.head(5)
# Out:
#         State Month  Unemployment_Rate      Date
# 0     Alabama   Jan                2.7  Jan-2020
# 1      Alaska   Jan                6.0  Jan-2020
# 2     Arizona   Jan                4.5  Jan-2020
# 3    Arkansas   Jan                3.5  Jan-2020
# 4  California   Jan                3.9  Jan-2020

# %%
unemployment_data_state.tail(5)
# Out:
#              State Month  Unemployment_Rate      Date
# 151     Washington   Mar                5.1  Mar-2020
# 152  West Virginia   Mar                6.1  Mar-2020
# 153      Wisconsin   Mar                3.4  Mar-2020
# 154        Wyoming   Mar                3.7  Mar-2020
# 155    Puerto Rico   Mar                NaN  Mar-2020

# %%
unemployment_data_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              156 non-null    object
#  1   Month              156 non-null    object
#  2   Unemployment_Rate  155 non-null    float64
#  3   Date               156 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 5.0+ KB

# %%
unemployment_data_state = unemployment_data_state.dropna()

# %%
unemployment_data_state['Date'] =pd.to_datetime(unemployment_data_state.Date)
unemployment_data_state = unemployment_data_state.sort_values(by='Date', ascending=True)

# %%
unemployment_data_state.isna().sum()
# Out:
# State                0
# Month                0
# Unemployment_Rate    0
# Date                 0
# dtype: int64

# %%
unemployment_data_state.describe()
# Out:
#        Unemployment_Rate
# count         155.000000
# mean            3.809677
# std             1.074484
# min             2.200000
# 25%             3.100000
# 50%             3.500000
# 75%             4.500000
# max             8.900000

# %%
print(unemployment_data_state[unemployment_data_state.State == 'New York'])
# Out:
#         State Month  Unemployment_Rate       Date
# 32   New York   Jan                3.8 2020-01-01
# 84   New York   Feb                3.6 2020-02-01
# 136  New York   Mar                4.5 2020-03-01

# %%
print(unemployment_data_state[unemployment_data_state.State == 'California'])
# Out:
#           State Month  Unemployment_Rate       Date
# 4    California   Jan                3.9 2020-01-01
# 56   California   Feb                2.5 2020-02-01
# 108  California   Mar                5.3 2020-03-01

# %%
print(unemployment_data_state[unemployment_data_state.State == 'North Carolina'])
# Out:
#               State Month  Unemployment_Rate       Date
# 33   North Carolina   Jan                3.6 2020-01-01
# 85   North Carolina   Feb                2.2 2020-02-01
# 137  North Carolina   Mar                4.4 2020-03-01

# %%
print(unemployment_data_state[unemployment_data_state.State == 'New Jersey'])
# Out:
#           State Month  Unemployment_Rate       Date
# 30   New Jersey   Jan                3.8 2020-01-01
# 82   New Jersey   Feb                4.8 2020-02-01
# 134  New Jersey   Mar                3.8 2020-03-01

# %%
plt.figure(figsize=(20,10))
plt.plot( 'Date', 'Unemployment_Rate', data=unemployment_data_state[unemployment_data_state.State == 'New York'], color='red')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.plot( 'Date', 'Unemployment_Rate', data=unemployment_data_state[unemployment_data_state.State == 'California'], color='red')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.plot( 'Date', 'Unemployment_Rate', data=unemployment_data_state[unemployment_data_state.State == 'North Carolina'], color='red')
plt.legend()

# %% [markdown]
# # Conclusion

# %% [markdown]
# We can see the rise in unemployment rate since the start of 2020. This may be the impact of COVID-19 and needs further analysis.
#
# *   Unemployment rate in the United States has affected everybody irrespective of education qualification, race, and gender.
# *   Highest impact is on the adults whose education level is Primary School.
# *   Highest impact is on the adults with hispanic race.
# *   Both genders are equally impacted.
# *   Unemployment Rates started increasing in states like New York, California, North Carolina.
#
# We need to further analyze this dataset by combining with COVID-19 dataset and understand the relationship between the 'unemployment rates' and 'Number of Confirmed COVID-19 cases'.
